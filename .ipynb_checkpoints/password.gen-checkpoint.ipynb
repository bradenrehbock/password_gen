# %%
import string
import secrets
import numpy as np

# %%
print(string.ascii_lowercase)
print(string.ascii_uppercase)
print(string.digits)
print(string.punctuation)
# Out:
# abcdefghijklmnopqrstuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
print(string.ascii_lowercase + string.digits)
# Out:
# abcdefghijklmnopqrstuvwxyz0123456789

# %%
pool = string.ascii_lowercase + string.digits

# %%
character_pool = []

for i in range(8):
    character_pool.append(secrets.choice(pool))

# %%
print(character_pool)
# Out:
# ['m', 'l', '2', 'q', 'y', '7', 'g', '3']

# %%
print("".join(character_pool))
# Out:
# ml2qy7g3

# %%
def gen_password(length, use_num):
    if length <= 0:
        raise ValueError("Password Length Must Be Greater Than 0")     
    character_pool = []
    pool = string.ascii_lowercase + string.ascii_uppercase + string.digits + string.punctuation
    pool_no_num = string.ascii_lowercase + string.ascii_uppercase + string.punctuation
    for i in range(length):
        if use_num:
            character_pool.append(secrets.choice(pool))
        else:
            character_pool.append(secrets.choice(pool_no_num))
    password = "".join(character_pool)
    return password

# %%
gen_password(7, use_num = True)
# Out:
# '~2O*l$I'

# %%
gen_password(-3, use_num = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 gen_password(-3, use_num = True)
#
# Cell In[143], line 3, in gen_password(length, use_num)
#       1 def gen_password(length, use_num):
#       2     if length <= 0:
# ----> 3         raise ValueError("Password Length Must Be Greater Than 0")
#       4     character_pool = []
#       5     pool = string.ascii_lowercase + string.ascii_uppercase + string.digits + string.punctuation
#
# ValueError: Password Length Must Be Greater Than 0
